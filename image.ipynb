# %%
import matplotlib.pyplot as plt
import matplotlib
# 指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei'] 
matplotlib.rcParams['font.family'] ='sans-serif'
# 解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False 
plt.rcParams['figure.dpi'] = 300 #分辨率
#  ac 1000 time: 0.01488184928894043

#  DRL_IOT 1000 time: 一次网络操作耗时： 0.038317203521728516
#训练一次所需时间time:  0.04428434371948242 

num_list = [0.01488184928894043,0.04428434371948242,]
x = [0.1,0.4]

x_label = ['演员-评论家','DRL-IOT:演员评论家']
plt.xticks(x,x_label)
plt.bar(x,num_list,width=0.1)
plt.ylabel('模型训练一次所花费的时间(单位s)')
plt.savefig('ac_tran_time.jpg')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib
# 指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei'] 
matplotlib.rcParams['font.family'] ='sans-serif'
# 解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False 
plt.rcParams['figure.dpi'] = 300 #分辨率
#  ac 1000 time: 0.01488184928894043

#  DRL_IOT 1000 time: 一次网络操作耗时： 0.038317203521728516
#训练一次所需时间time:  0.04428434371948242 
# 0.0010075549998873612 
# 0.00029302699999789183
num_list = [1.0075549998873612,0.29302699999789183,]
x = [0.1,0.4]

x_label = ['演员-评论家','DRL-IOT:演员评论家']
plt.xticks(x,x_label)
plt.bar(x,num_list,width=0.1)
plt.ylabel('模型预测一次所花费的时间（单位：0.001s）')
plt.savefig('ac_predict_time.jpg')
plt.show()

# %%
# 参数量： 存储空间大小
# 17,281: 71.68 kB
# 386: 1.6 kB
import matplotlib.pyplot as plt
import matplotlib
# 指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei'] 
matplotlib.rcParams['font.family'] ='sans-serif'
# 解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False 
plt.rcParams['figure.dpi'] = 300 #分辨率
#  ac 1000 time: 0.01488184928894043

#  DRL_IOT 1000 time: 一次网络操作耗时： 0.038317203521728516
#训练一次所需时间time:  0.04428434371948242 
# 0.0010075549998873612 
# 0.00029302699999789183
num_list = [17281,386,]
x = [0.1,0.4]

x_label = ['传统演员-评论家','DRL-IOT:演员']
plt.xticks(x,x_label)
plt.bar(x,num_list,width=0.1)
plt.ylabel('部署在物联网设备模型参数量（单位：KB）')
plt.savefig('ac_predict_model.jpg')
plt.show()

# %%
import matplotlib.pyplot as plt
 
name_list = ['train','predict']
num_list = [17281,71.68,] # 
num_list1 = [386,1.6,] # 网络耗时  0.036 * 1000 / 5 = 7.2 predict time: 0.00031271800000354233
x =list(range(len(num_list)))
total_width, n = 0.8, 2
width = total_width / n
 
plt.bar(x, num_list, width=width, label='boy',fc = 'y')
for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x, num_list1, width=width, label='girl',tick_label = name_list,fc = 'r')
plt.legend()
plt.show()

# %%
#20.8, 21.7, 22.5, 26.6, 20.9, 19.9, 23.7, 31.4, 41.0, 41.4, 53.2, 40.4, 46.0, 29.0, 59.5, 77.6, 74.7, 57.0, 83.4, 125.5, 138.4, 113.8, 151.3, 84.6, 126.1, 185.7, 124.2, 126.9, 70.9, 61.4, 115.7, 119.1, 130.2, 75.2, 83.8, 117.8, 170.9, 196.6, 85.9, 60.2, 134.4, 175.3, 182.1, 192.2, 196.7, 162.8, 200.0, 200.0, 193.5, 147.1, 185.7, 195.9, 132.4, 185.5, 194.4, 192.7, 200.0, 175.0, 87.1, 120.1, 200.0, 200.0, 192.5, 197.7, 159.9, 143.1, 147.7, 177.4, 141.4, 75.6, 80.4, 72.0, 76.7, 60.9, 36.8, 50.8, 52.2, 62.9, 95.0, 106.7, 100.7, 112.4, 200.0, 186.1, 200.0, 200.0, 199.7
# 倒立摆问题，折线图：
y = [20.8, 21.7, 22.5, 26.6, 20.9, 19.9, 23.7, 31.4, 41.0, 41.4, 53.2, 40.4, 46.0, 29.0, 59.5, 77.6, 74.7, 57.0, 83.4, 125.5, 138.4, 113.8, 151.3, 84.6, 126.1, 185.7, 124.2, 126.9, 70.9, 61.4, 115.7, 119.1, 130.2, 75.2, 83.8, 117.8, 170.9, 196.6, 85.9, 60.2, 134.4, 175.3, 182.1, 192.2, 196.7, 162.8, 200.0, 200.0, 193.5, 147.1, 185.7, 195.9, 132.4, 185.5, 194.4, 192.7, 200.0, 175.0, 87.1, 120.1, 200.0, 200.0, 192.5, 197.7, 159.9, 143.1, 147.7, 177.4, 141.4, 75.6, 80.4, 72.0, 76.7, 95.0, 106.7, 100.7, 112.4, 200.0, 186.1, 200.0, 200.0, 199.7]
x = [x for x in range(len(y))]
plt.plot(x,y)
# plt.title('基于DRL-IOT框架演员-评论家算法测试得分图')
plt.xlabel('训练次数 单位（千）')
plt.ylabel('在倒立摆问题中的得分')
plt.savefig('ac_tran_process.jpg')

# %%
# ddpg vanila train : 0.009273634786715083 1万次训练的平均耗时
# predict: 0.00017200446128845214
# DRL_IOT: 0.03453307908781307, predict: 0.00014290196905203628
# 参数量 0.07， 0.26 * 2 + 0.07 * 2

# %%
# 训练过程数据： [-1257.6232564669585, -1783.8891533662209, -1484.4791639909158, -1429.4557821301764, -1451.3567126493401, -1448.0465114657509, -1441.464720859088, -1376.8405289698762, -1422.0415343519776, -1405.8040878631787, -1354.4259210128425, -1353.3469701535234, -1390.3875693863943, -1432.4162354626974, -1406.5460000873607, -1343.9019821336958, -1379.47716200763, -1350.731877742212, -1343.5007504443831, -1265.6942009235581, -1213.5545163845368, -886.6769838502427, -1319.5078955666208, -1449.9067822179604, -1434.1533979224118, -1315.8221623786917, -1334.5832158803528, -1354.4191581176426, -1417.6267037832756, -1093.8918814953868, -943.7609505886288, -856.5384828009076, -722.9975389352273, -550.3655314843115, -905.8655976019893, -734.2348746636596, -509.8283234105582, -329.0071040482897, -225.71654537667808, -163.8020382546049, -163.8644818666305, -188.87695521804616, -231.44543256729577, -163.13863596299035, -127.75394855616294, -180.53394517620416, -153.03833221712318, -190.16383657682482, -154.14098848987615, -200.42445496145896, -83.76615585747211]

# %%
# 模型训练时间：
import matplotlib.pyplot as plt
import matplotlib
# 指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei'] 
matplotlib.rcParams['font.family'] ='sans-serif'
# 解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False 
plt.rcParams['figure.dpi'] = 300 #分辨率

num_list = [0.009273634786715083,0.03453307908781307,]
x = [0.1,0.4]
x_label = ['DDPG','DRL-IOT:DDPG']
plt.xticks(x,x_label)
plt.bar(x,num_list,width=0.1)
plt.ylabel('模型训练一次所花费的时间(单位s)')
plt.savefig('ddpg_tran_time.jpg')
plt.show()

# %%
# 模型预测时间：
import matplotlib.pyplot as plt
import matplotlib
# 指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei'] 
matplotlib.rcParams['font.family'] ='sans-serif'
# 解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False 
plt.rcParams['figure.dpi'] = 300 #分辨率
num_list = [00001.7200446128845214,00001.4290196905203628,]
x = [0.1,0.4]
x_label = ['DDPG','DRL-IOT:DDPG']
plt.xticks(x,x_label)
plt.bar(x,num_list,width=0.1)
plt.ylabel('模型预测一次所花费的时间(单位0.0001s)')
plt.savefig('ddpg_pre_time.jpg')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib
# 指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei'] 
matplotlib.rcParams['font.family'] ='sans-serif'
# 解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False 
plt.rcParams['figure.dpi'] = 300 #分辨率
num_list = [0.66,0.07,]
x = [0.1,0.4]
x_label = ['DDPG','DRL-IOT:DDPG']
plt.xticks(x,x_label)
plt.bar(x,num_list,width=0.1)
plt.ylabel('部署在物联网设备模型参数量（单位：MB）')
plt.savefig('ddpg_predict_model.jpg')
plt.show()

# %%
#折线图：
y = [-1257.6232564669585, -1783.8891533662209, -1484.4791639909158, -1429.4557821301764, -1451.3567126493401, -1448.0465114657509, -1441.464720859088, -1376.8405289698762, -1422.0415343519776, -1405.8040878631787, -1354.4259210128425, -1353.3469701535234, -1390.3875693863943, -1432.4162354626974, -1406.5460000873607, -1343.9019821336958, -1379.47716200763, -1350.731877742212, -1343.5007504443831, -1265.6942009235581, -1213.5545163845368, -886.6769838502427, -1319.5078955666208, -1449.9067822179604, -1434.1533979224118, -1315.8221623786917, -1334.5832158803528, -1354.4191581176426, -1417.6267037832756, -1093.8918814953868, -943.7609505886288, -856.5384828009076, -722.9975389352273, -550.3655314843115, -905.8655976019893, -734.2348746636596, -509.8283234105582, -329.0071040482897, -225.71654537667808, -163.8020382546049, -163.8644818666305, -188.87695521804616, -231.44543256729577, -163.13863596299035, -127.75394855616294, -180.53394517620416, -153.03833221712318, -190.16383657682482, -154.14098848987615, -200.42445496145896, -83.76615585747211]
x = [x*200 for x in range(len(y))]
plt.plot(x,y)
plt.xlabel('训练次数')
plt.ylabel('在单摆问题中的得分')
plt.savefig('ddpg_tran_process.jpg')
